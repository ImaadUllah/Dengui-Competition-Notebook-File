# %%
import pandas as pd
import numpy as np

# %%
training_data = pd.read_csv(r'D:\data\dengue_features_train.csv')
training_data.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18       4/30/1990  0.122600  0.103725  0.198483
# 1   sj  1990          19        5/7/1990  0.169900  0.142175  0.162357
# 2   sj  1990          20       5/14/1990  0.032250  0.172967  0.157200
# 3   sj  1990          21       5/21/1990  0.128633  0.245067  0.227557
# 4   sj  1990          22       5/28/1990  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k     ...       \
# 0  0.177617                 12.42             297.572857     ...
# 1  0.155486                 22.82             298.211429     ...
# 2  0.170843                 34.54             298.781429     ...
# 3  0.235886                 15.36             298.987143     ...
# 4  0.247340                  7.52             299.518571     ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# ...

# %%
testing_data = pd.read_csv(r'D:\data\dengue_features_test.csv')
testing_data.head()
# Out:
#   city  year  weekofyear week_start_date  ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  2008          18      2008-04-29  -0.0189 -0.018900  0.102729
# 1   sj  2008          19      2008-05-06  -0.0180 -0.012400  0.082043
# 2   sj  2008          20      2008-05-13  -0.0015       NaN  0.151083
# 3   sj  2008          21      2008-05-20      NaN -0.019867  0.124329
# 4   sj  2008          22      2008-05-27   0.0568  0.039833  0.062267
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k        ...          \
# 0  0.091200                 78.60             298.492857        ...
# 1  0.072314                 12.56             298.475714        ...
# 2  0.091529                  3.66             299.455714        ...
# 3  0.125686                  0.00             299.690000        ...
# 4  0.075914                  0.76             299.780000        ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# ...

# %%
train_data = training_data
test_data = testing_data

# %%
train_data.shape
# Out:
# (1456, 25)

# %%
test_data.shape
# Out:
# (416, 24)

# %% [markdown]
# ### We don't need week_start_date column so we will remove that both from test and train

# %%
# test_data.drop('week_start_date', axis=1, inplace=True)
# train_data.drop('week_start_date', axis=1, inplace=True)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
# city                                     1456 non-null object
# year                                     1456 non-null int64
# weekofyear                               1456 non-null int64
# ndvi_ne                                  1262 non-null float64
# ndvi_nw                                  1404 non-null float64
# ndvi_se                                  1434 non-null float64
# ndvi_sw                                  1434 non-null float64
# precipitation_amt_mm                     1443 non-null float64
# reanalysis_air_temp_k                    1446 non-null float64
# reanalysis_avg_temp_k                    1446 non-null float64
# reanalysis_dew_point_temp_k              1446 non-null float64
# reanalysis_max_air_temp_k                1446 non-null float64
# reanalysis_min_air_temp_k                1446 non-null float64
# ...

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 23 columns):
# city                                     416 non-null object
# year                                     416 non-null int64
# weekofyear                               416 non-null int64
# ndvi_ne                                  373 non-null float64
# ndvi_nw                                  405 non-null float64
# ndvi_se                                  415 non-null float64
# ndvi_sw                                  415 non-null float64
# precipitation_amt_mm                     414 non-null float64
# reanalysis_air_temp_k                    414 non-null float64
# reanalysis_avg_temp_k                    414 non-null float64
# reanalysis_dew_point_temp_k              414 non-null float64
# reanalysis_max_air_temp_k                414 non-null float64
# reanalysis_min_air_temp_k                414 non-null float64
# ...

# %%
train_data.describe(include='all')
# Out:
#         city         year   weekofyear      ndvi_ne      ndvi_nw      ndvi_se  \
# count   1456  1456.000000  1456.000000  1262.000000  1404.000000  1434.000000
# unique     2          NaN          NaN          NaN          NaN          NaN
# top       sj          NaN          NaN          NaN          NaN          NaN
# freq     936          NaN          NaN          NaN          NaN          NaN
# mean     NaN  2001.031593    26.503434     0.142294     0.130553     0.203783
# std      NaN     5.408314    15.019437     0.140531     0.119999     0.073860
# min      NaN  1990.000000     1.000000    -0.406250    -0.456100    -0.015533
# 25%      NaN  1997.000000    13.750000     0.044950     0.049217     0.155087
# 50%      NaN  2002.000000    26.500000     0.128817     0.121429     0.196050
# 75%      NaN  2005.000000    39.250000     0.248483     0.216600     0.248846
# max      NaN  2010.000000    53.000000     0.508357     0.454429     0.538314
#
# ...

# %%
test_data.describe(include='all')
# Out:
#        city         year  weekofyear     ndvi_ne     ndvi_nw     ndvi_se  \
# count   416   416.000000  416.000000  373.000000  405.000000  415.000000
# unique    2          NaN         NaN         NaN         NaN         NaN
# top      sj          NaN         NaN         NaN         NaN         NaN
# freq    260          NaN         NaN         NaN         NaN         NaN
# mean    NaN  2010.766827   26.439904    0.126050    0.126803    0.207702
# std     NaN     1.434835   14.978257    0.164353    0.141420    0.079102
# min     NaN  2008.000000    1.000000   -0.463400   -0.211800    0.006200
# 25%     NaN  2010.000000   13.750000   -0.001500    0.015975    0.148670
# 50%     NaN  2011.000000   26.000000    0.110100    0.088700    0.204171
# 75%     NaN  2012.000000   39.000000    0.263329    0.242400    0.254871
# max     NaN  2013.000000   53.000000    0.500400    0.649000    0.453043
#
#            ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# ...

# %%
train_data.dtypes
# Out:
# city                                      object
# year                                       int64
# weekofyear                                 int64
# ndvi_ne                                  float64
# ndvi_nw                                  float64
# ndvi_se                                  float64
# ndvi_sw                                  float64
# precipitation_amt_mm                     float64
# reanalysis_air_temp_k                    float64
# reanalysis_avg_temp_k                    float64
# reanalysis_dew_point_temp_k              float64
# reanalysis_max_air_temp_k                float64
# reanalysis_min_air_temp_k                float64
# reanalysis_precip_amt_kg_per_m2          float64
# reanalysis_relative_humidity_percent     float64
# reanalysis_sat_precip_amt_mm             float64
# reanalysis_specific_humidity_g_per_kg    float64
# reanalysis_tdtr_k                        float64
# station_avg_temp_c                       float64
# ...

# %%
test_data.dtypes
# Out:
# city                                      object
# year                                       int64
# weekofyear                                 int64
# ndvi_ne                                  float64
# ndvi_nw                                  float64
# ndvi_se                                  float64
# ndvi_sw                                  float64
# precipitation_amt_mm                     float64
# reanalysis_air_temp_k                    float64
# reanalysis_avg_temp_k                    float64
# reanalysis_dew_point_temp_k              float64
# reanalysis_max_air_temp_k                float64
# reanalysis_min_air_temp_k                float64
# reanalysis_precip_amt_kg_per_m2          float64
# reanalysis_relative_humidity_percent     float64
# reanalysis_sat_precip_amt_mm             float64
# reanalysis_specific_humidity_g_per_kg    float64
# reanalysis_tdtr_k                        float64
# station_avg_temp_c                       float64
# ...

# %%
train_data.isnull().any()
# Out:
# city                                     False
# year                                     False
# weekofyear                               False
# ndvi_ne                                  False
# ndvi_nw                                  False
# ndvi_se                                  False
# ndvi_sw                                  False
# precipitation_amt_mm                     False
# reanalysis_air_temp_k                    False
# reanalysis_avg_temp_k                    False
# reanalysis_dew_point_temp_k              False
# reanalysis_max_air_temp_k                False
# reanalysis_min_air_temp_k                False
# reanalysis_precip_amt_kg_per_m2          False
# reanalysis_relative_humidity_percent     False
# reanalysis_sat_precip_amt_mm             False
# reanalysis_specific_humidity_g_per_kg    False
# reanalysis_tdtr_k                        False
# station_avg_temp_c                       False
# station_diur_temp_rng_c                  False
# ...

# %%
test_data.isnull().any()
# Out:
# city                                     False
# year                                     False
# weekofyear                               False
# ndvi_ne                                  False
# ndvi_nw                                  False
# ndvi_se                                  False
# ndvi_sw                                  False
# precipitation_amt_mm                     False
# reanalysis_air_temp_k                    False
# reanalysis_avg_temp_k                    False
# reanalysis_dew_point_temp_k              False
# reanalysis_max_air_temp_k                False
# reanalysis_min_air_temp_k                False
# reanalysis_precip_amt_kg_per_m2          False
# reanalysis_relative_humidity_percent     False
# reanalysis_sat_precip_amt_mm             False
# reanalysis_specific_humidity_g_per_kg    False
# reanalysis_tdtr_k                        False
# station_avg_temp_c                       False
# station_diur_temp_rng_c                  False
# ...

# %%
train_data.fillna(method='ffill', inplace=True)

test_data.fillna(method='ffill', inplace=True)

# %%
train_data['city'] = train_data['city'].astype('category') 
train_data['city'] = train_data['city'].cat.codes

test_data['city'] = test_data['city'].astype('category') 
test_data['city'] = test_data['city'].cat.codes

# %%
train_data.shape
# Out:
# (1456, 24)

# %%
test_data.shape
# Out:
# (416, 23)

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
x_training = train_data.drop(['total_cases'], 1)
y_training = train_data['total_cases']
x_train, x_test, y_train, y_test = train_test_split(x_training, y_training, test_size=0.2852, random_state=1)

# %%
x_training.shape
# Out:
# (1456, 23)

# %%
x_test.shape
# Out:
# (416, 23)

# %%
y_test.shape
# Out:
# (416,)

# %%
y_training.shape
# Out:
# (1456,)

# %%
y_train.shape
# Out:
# (1040,)

# %%
from sklearn.metrics import mean_absolute_error
regression_model = LinearRegression()
regression_model.fit(x_train, y_train)
y_predicted = regression_model.predict(x_test)

print('Mean Absolute Error:', mean_absolute_error(y_test, y_predicted))
# Out:
# Mean Absolute Error: 21.534291860097238

# %%
regression_model.fit(x_training, y_training)
y_predicted = regression_model.predict(test_data)

print('Mean Absolute Error:', mean_absolute_error(y_test, y_predicted))
# Out:
# Mean Absolute Error: 25.719435822676953

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
clf = linear_model.Ridge(alpha = 44)
clf.fit(x_train, y_train)
Y_pred = clf.predict(x_test)
mean_absolute_error(y_test, Y_pred)
# Out:
# 20.540002787457944

# %%
clf.fit(x_training, y_training)
Y_pred = clf.predict(test_data)
mean_absolute_error(y_test, Y_pred)
# Out:
# 24.81846965257342

# %%
from sklearn.ensemble import RandomForestRegressor
RFR = RandomForestRegressor(max_depth=2, random_state=0, n_estimators=100)
RFR.fit(x_train, y_train)
y_ = RFR.predict(x_test)
print('Mean Absolute Error:', mean_absolute_error(y_test, y_))
# Out:
# Mean Absolute Error: 16.107140122630064

# %%
from sklearn.ensemble import RandomForestRegressor
RFR = RandomForestRegressor(max_depth=2, random_state=42, n_estimators=100)
RFR.fit(x_training, y_training)
y_ = RFR.predict(test_data)
print('Mean Absolute Error:', mean_absolute_error(y_test, y_))
# Out:
# Mean Absolute Error: 18.901098497855102

# %%
from sklearn.model_selection import GridSearchCV
RFclfParameters = [{'n_estimators': [100, 500], 'max_features': ["log2","sqrt"]}]
GridSearchRF = GridSearchCV(estimator = RFR, param_grid = RFclfParameters, scoring = 'neg_mean_absolute_error', cv = 10, n_jobs = -1)

# %%
GridSearchRF.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=2,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#            oob_score=False, random_state=42, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid=[{'n_estimators': [100, 500], 'max_features': ['log2', 'sqrt']}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_absolute_error', verbose=0)

# %%
yy = GridSearchRF.predict(x_test)
print('Mean Absolute Error:', mean_absolute_error(y_test, yy))
# Out:
# Mean Absolute Error: 17.759270883539184

# %%
GridSearchRF.fit(x_training, y_training)
y = GridSearchRF.predict(test_data)
print('Mean Absolute Error:', mean_absolute_error(y_test, y))
# Out:
# C:\Users\LAYI\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# Mean Absolute Error: 22.27534290001084

# %%
y
# Out:
# array([19.58874184, 25.15745433, 20.05240568, 26.3679106 , 33.91630752,
#        27.63665103, 26.52466567, 27.52660816, 28.77434023, 29.05469157,
#        28.63905136, 29.45463315, 29.68858602, 32.67644751, 35.00083063,
#        47.86844327, 34.85359477, 37.67805435, 44.53169132, 34.7033627 ,
#        37.08851691, 34.10569091, 34.26803937, 36.52284013, 32.11954274,
#        34.37914057, 47.40353613, 35.95580287, 35.43757825, 34.07746891,
#        31.74275637, 25.97114106, 26.93231182, 28.84873434, 24.4020839 ,
#        17.86663256, 19.01562828, 22.43378097, 19.93514205, 20.56168582,
#        19.39642819, 19.95100623, 19.75558151, 18.14733485, 19.48898418,
#        24.41779792, 19.52617391, 18.63973364, 18.98372761, 19.21966695,
#        19.46815827, 19.45105588, 21.15422835, 23.93932146, 23.64488337,
#        21.1174719 , 26.5659491 , 26.38699369, 36.69629853, 28.37786459,
#        29.14931733, 28.63765228, 30.27463876, 30.31930509, 31.40376392,
# ...

# %%
df = pd.read_csv(r'E:\SZABIST\1st Semester\Tools and Techniques for Data Science (Muazz)\Final Project T&T\dengue_features_test.csv')
df.shape
# Out:
# (416, 24)

# %%
df.head()
# Out:
#   city  year  weekofyear week_start_date  ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  2008          18       4/29/2008  -0.0189 -0.018900  0.102729
# 1   sj  2008          19        5/6/2008  -0.0180 -0.012400  0.082043
# 2   sj  2008          20       5/13/2008  -0.0015 -0.012400  0.151083
# 3   sj  2008          21       5/20/2008  -0.0015 -0.019867  0.124329
# 4   sj  2008          22       5/27/2008   0.0568  0.039833  0.062267
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k        ...          \
# 0  0.091200                 78.60             298.492857        ...
# 1  0.072314                 12.56             298.475714        ...
# 2  0.091529                  3.66             299.455714        ...
# 3  0.125686                  0.00             299.690000        ...
# 4  0.075914                  0.76             299.780000        ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# ...

# %%
df = df.iloc[:, 0:3]
df['total_cases'] = y
df['total_cases'] = df['total_cases'].astype(int)
df
# Out:
#     city  year  weekofyear  total_cases
# 0     sj  2008          18           19
# 1     sj  2008          19           25
# 2     sj  2008          20           20
# 3     sj  2008          21           26
# 4     sj  2008          22           33
# 5     sj  2008          23           27
# 6     sj  2008          24           26
# 7     sj  2008          25           27
# 8     sj  2008          26           28
# 9     sj  2008          27           29
# 10    sj  2008          28           28
# 11    sj  2008          29           29
# 12    sj  2008          30           29
# 13    sj  2008          31           32
# 14    sj  2008          32           35
# 15    sj  2008          33           47
# 16    sj  2008          34           34
# 17    sj  2008          35           37
# 18    sj  2008          36           44
# 19    sj  2008          37           34
# 20    sj  2008          38           37
# 21    sj  2008          39           34
# ...

# %%
submit = df
submit.to_csv(r'E:\SZABIST\1st Semester\Tools and Techniques for Data Science (Muazz)\Final Project T&T\submit10.csv')
